# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as  sns
# %matplotlib inline

df = pd.read_excel('surveys.xlsx')
is_ques_no = df['question']==1
q_df = df[is_ques_no]
#q_df

#plt.figure(figsize=(20,9))
sns.lineplot(x='week', y= 'score', data=q_df, estimator='mean')


#>gapminder_2002 = gapminder[is_2002]
#>print(gapminder_2002.shape)
