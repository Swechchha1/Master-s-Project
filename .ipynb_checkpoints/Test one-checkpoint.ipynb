# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as  sns
# %matplotlib inline

df = pd.read_excel('surveys.xlsx')



sns.relplot(x='week', y='score', data=df,
            kind='line', hue='question', col='question', estimator='mean')




'''
fig, axes = plt.subplots(2)
df[df.question == 1].pointplot(x='week', y= 'score',ax=axes[0]).set_ylabel('question 1')
#df[df.question == 2].plot(x='week', y= 'score',ax=axes[1]).set_ylabel('question 2')
#df[df.question == 3].plot(x='week', y= 'score',ax=axes[2]).set_ylabel('question 3')

plt.show()
'''

'''
fig, ax = plt.subplots()

for key, grp in df.groupby(['question']):
    ax = grp.plot(ax=ax, kind='line', x='week', y='score')

plt.legend(loc='best')
plt.show()

'''
# Out:
# "\nfig, ax = plt.subplots()\n\nfor key, grp in df.groupby(['question']):\n    ax = grp.plot(ax=ax, kind='line', x='week', y='score')\n\nplt.legend(loc='best')\nplt.show()\n\n"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as  sns
# %matplotlib inline

df = pd.read_excel('surveys.xlsx')
is_week_no = df['week']==12
w_df = df[is_week_no]


w_df['score'].hist(bins=10)
